# %% [markdown]
# <a href="https://colab.research.google.com/github/ROSHAN-KUMAR-NAYAK/Retail--customer-360-sales-analysis/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Pandas

# %%
import pandas as pd

# %% [markdown]
# Load The Data Set

# %%
df=pd.read_csv("/content/CSV Cleaned_Analytics_Dataset.csv")
df
# Out:
#       Order_ID Customer_Id  Order_Date Region Product_Category  \
# 0            4    CUST7938  19-07-2024  North         Clothing
# 1            6    CUST4834  22-10-2024  North           Sports
# 2           18    CUST3460  30-05-2024   West   Home & Kitchen
# 3           30    CUST5248  10-01-2024  North      Electronics
# 4           52    CUST5763  04-07-2024   West           Beauty
# ...        ...         ...         ...    ...              ...
# 9995      9948    CUST6667  05-10-2024  South      Electronics
# 9996      9955    CUST2908  03-10-2024   East      Electronics
# 9997      9965    CUST4527  15-05-2024  South         Clothing
# 9998      9981    CUST6031  13-02-2024   West         Clothing
# 9999      9999    CUST9750  13-05-2024   East           Sports
#
#      Customer_Segment  Quantity  Unit_Price  Discount_Rate  Revenue     Cost  \
# 0            Consumer         1      444.50           0.06   417.83   280.99
# 1            Consumer         1      253.38           0.01   250.85   164.50
# 2         Home Office         1       78.16           0.22    60.96    48.32
# 3            Consumer         1      212.23           0.17   176.15   117.51
# 4            Consumer         1      303.08           0.05   287.93   168.17
# ...               ...       ...         ...            ...      ...      ...
# 9995      Home Office        10      426.18           0.17  3537.29  2488.86
# 9996         Consumer        10       22.00           0.04   211.20   136.15
# 9997         Consumer        10      494.03           0.13  4298.06  2965.95
# 9998        Corporate        10      254.70           0.23  1961.19  1249.36
# 9999      Home Office        10      303.63           0.17  2520.13  1455.60
#
#        Profit    Payment_Method
# 0      136.84               UPI
# 1       86.35       Credit Card
# 2       12.64       Credit Card
# 3       58.64       Net Banking
# 4      119.76       Credit Card
# ...       ...               ...
# 9995  1048.43       Credit Card
# 9996    75.05  Cash on Delivery
# 9997  1332.11  Cash on Delivery
# 9998   711.83  Cash on Delivery
# 9999  1064.53  Cash on Delivery
#
# [10000 rows x 13 columns]

# %% [markdown]
# Create The Python Script In Colab

# %%
# %%writefile etl_pipeline.py

import pandas as pd

# Load dataset
df = pd.read_csv("/content/CSV Cleaned_Analytics_Dataset.csv")

# Convert date
df['Order_Date'] = pd.to_datetime(df['Order_Date'])

# Create RFM metrics
today = df['Order_Date'].max()

rfm = df.groupby("Customer_Id").agg({
    "Order_Date": lambda x: (today - x.max()).days,
    "Order_ID": "count",
    "Revenue": "sum"
})

rfm.columns = ["Recency","Frequency","Monetary"]

# Identify churn customers
rfm["Churn_Risk"] = "No"
rfm.loc[(rfm["Recency"] > 90) & (rfm["Frequency"] < 3),"Churn_Risk"] = "Yes"

# Save output
rfm.to_csv("Churn_Risk_Customers.csv")

print("ETL Pipeline Completed Successfully")
# Out:
# Overwriting etl_pipeline.py

# %% [markdown]
# Run The Script

# %%
# !python etl_pipeline.py
# Out:
# /content/etl_pipeline.py:8: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Order_Date'] = pd.to_datetime(df['Order_Date'])
# ETL Pipeline Completed Successfully

# %% [markdown]
# Check Output File

# %%
# !ls
# Out:
#  Churn_Risk_Customers.csv	      etl_pipeline.py
# 'CSV Cleaned_Analytics_Dataset.csv'   sample_data

# %% [markdown]
# Download Result

# %%
from google.colab import files
files.download("/content/Churn_Risk_Customers.csv")

# %% [markdown]
# Automate The Python ETL Script

# %%
import pandas as pd

df = pd.read_csv("/content/CSV Cleaned_Analytics_Dataset.csv")

df['Order_Date'] = pd.to_datetime(df['Order_Date'], dayfirst=True)

today = df['Order_Date'].max()

rfm = df.groupby("Customer_Id").agg({
    "Order_Date": lambda x: (today - x.max()).days,
    "Order_ID": "count",
    "Revenue": "sum"
})

rfm.columns = ["Recency","Frequency","Monetary"]

rfm["Churn_Risk"] = "No"
rfm.loc[(rfm["Recency"] > 90) & (rfm["Frequency"] < 3),"Churn_Risk"]="Yes"

rfm.to_csv("Churn_Risk_Customers.csv")
